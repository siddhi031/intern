# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([12,34,56,23,78,90,98,22,10,45]) 
y = np.array([11,33,55,24,79,89,97,21,9,44])    
z= np.array([13,35,56,26,80,95,25,5,7,1])

# %% [markdown]
# # line plot

# %%
plt.plot(x,y);

# %%
plt.title('line plot')
plt.xlabel('x values')
plt.ylabel('y value')
plt.plot(x,y,color='red',marker='o',mfc='blue',ls='--')
plt.grid()

# %%
plt.title('line plot')
plt.xlabel('x values')
plt.ylabel('z value')
plt.plot(x,z,color='magenta',marker='>',mfc='blue',ls='--')
plt.grid()

# %%
plt.title('line plot')
plt.xlabel('x values')
plt.ylabel('z value')
plt.plot(x,color='red',marker='o',mfc='blue',ls='--')
plt.plot(z,color='black',marker='o',mfc='blue',ls='--')
plt.grid()

# %%
plt.subplot(2,2,1)
plt.title('line plot')
plt.xlabel('x values')
plt.ylabel('y value')
plt.plot(x,y,color='red',marker='o',mfc='blue',ls='--')
plt.grid()


plt.subplot(2,2,2)
plt.xlabel('x values')
plt.ylabel('z value')
plt.plot(x,color='red',marker='o',mfc='blue',ls='--')
plt.plot(z,color='black',marker='o',mfc='blue',ls='--')
plt.grid()

# %%
plt.figure(figsize)
plt.subplot(2,2,1)
plt.title('line plot')
plt.xlabel('x values')
plt.ylabel('y value')
plt.plot(x,y,color='red',marker='o',mfc='blue',ls='--')
plt.grid()


plt.subplot(2,2,2)
plt.xlabel('x values')
plt.ylabel('z value')
plt.plot(x,color='red',marker='o',mfc='blue',ls='--')
plt.plot(z,color='black',marker='o',mfc='blue',ls='--')
plt.grid()

# %% [markdown]
# # bar graph

# %%
courses = ['python','dart','java','php','ruby']
students = [34,56,78,90,12]

# %%
plt.bar(courses,students)
plt.grid()

# %%
plt.title('student enrollment')
plt.xlabel('courses')
plt.ylabel('students')
plt.bar(courses,students,color='pink',width=0.3,edgecolor='black');
plt.grid()

# %% [markdown]
# # load student.csv plot marks by student name bar graph

# %%
data = pd.read_csv("student.csv")

# %%
data
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
plt.figure(figsize=(16,9))
plt.title('student progess')
plt.xlabel('name')
plt.ylabel('marks')
plt.bar(data.name,data.marks,color='pink',width=0.4,edgecolor='black');
plt.grid()

# %% [markdown]
# ### data => Social_network_ads.csv
# ### location => https://mitu.co.in/dataset
# ### plot the bar to check how many people purchase product and how many not

# %%
df = pd.read_csv("Social_Network_Ads.csv")
df.head()
# Out:
#     User ID  Gender   Age  EstimatedSalary  Purchased
# 0  15624510    Male  19.0          19000.0          0
# 1  15810944    Male  35.0          20000.0          0
# 2  15668575  Female  26.0          43000.0          0
# 3  15603246  Female  27.0          57000.0          0
# 4  15804002    Male  19.0          76000.0          0

# %%
df['Purchased'].value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
df['Purchased'].value_counts().index
# Out:
# Index([0, 1], dtype='int64', name='Purchased')

# %%
plt.xticks(range(0,2,1))
plt.bar(df['Purchased'].value_counts().index,
       df['Purchased'].value_counts(),color='orange',edgecolor='black');

# %% [markdown]
# # histogram

# %%
data1 = np.random.randn(1000)

# %%
data1
# Out:
# array([-1.80190774e+00,  3.44133958e-01,  1.19830140e+00, -1.57820496e+00,
#         9.75069548e-02, -1.55822726e+00,  6.81316363e-01,  1.55822591e+00,
#         1.22890101e+00, -7.57803458e-01,  1.26070870e+00,  2.01016798e-02,
#        -9.45025249e-01, -6.09267574e-02,  1.45593899e-01, -1.14729864e+00,
#         2.00566275e-01, -4.17119576e-01,  4.65341784e-01,  1.41287716e+00,
#         2.53760815e-01, -1.88894473e+00, -1.56813877e+00, -1.28890823e+00,
#         2.92592676e-01,  8.53797614e-01,  9.38711017e-01,  6.94780298e-01,
#        -2.18219468e-01, -1.00905011e+00,  2.93799235e-01, -6.28381365e-01,
#         5.31081721e-01, -7.78415355e-01,  1.65490939e+00,  2.23875093e+00,
#        -4.11826322e-01, -9.00710408e-01, -1.51082637e+00, -1.13071615e+00,
#         1.32509350e+00, -4.62566980e-01, -5.74291992e-01,  8.88697755e-01,
#         6.65015853e-01, -1.95014220e+00, -1.40713826e+00, -1.47589925e+00,
# ...

# %%
plt.figure(figsize=(16,9))
plt.hist(data1,bins=30,color='black');
plt.grid()

# %% [markdown]
# # scatter plot

# %%
plt.scatter(x,y,marker='>');
plt.grid()

# %% [markdown]
# ## pie chart

# %%
plt.pie(students,labels = courses,autopct='%.2f%%',explode = [0,0.2,0,0,0]);

# %%
# take any four plots from above and put them in a same figure

# %%
plt.figure(figsize=(16,9))

plt.subplot(2,2,1)
plt.title('student enrollment')
plt.xlabel('courses')
plt.ylabel('students')
plt.bar(courses,students,color='pink',width=0.3,edgecolor='black');
plt.grid()


plt.subplot(2,2,2)
plt.title('student progess')
plt.xlabel('name')
plt.ylabel('marks')
plt.bar(data.name,data.marks,color='pink',width=0.4,edgecolor='black');
plt.grid()

plt.subplot(2,2,3)
plt.pie(students,labels = courses,autopct='%.2f%%',explode = [0,0.2,0,0,0]);


plt.subplot(2,2,4)
plt.xticks(range(0,2,1))
plt.bar(df['Purchased'].value_counts().index,
       df['Purchased'].value_counts(),color='orange',edgecolor='black');

plt.savefig('my_plot.png')

# %% [markdown]
# # Problem

# %% [markdown]
# ### 1. import matplotlib.pyplot and create a basic line plot showing fare values of the first 10 passenger

# %%
df1 = pd.read_csv("train.csv")
df1.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.plot(df1['Fare'].head(10))

# Adding labels and title
plt.title('Fare of First 10 Titanic Passengers')
plt.xlabel('Passenger Index')
plt.ylabel('Fare')

plt.show()

# %% [markdown]
# ### 2. create a bar chart showing the no of passenger in each class(Pclass).

# %%
import matplotlib.pyplot as plt

# Count passengers in each class
pclass_counts = df1['Pclass'].value_counts().sort_index()

# Create bar chart
plt.bar(pclass_counts.index, pclass_counts.values,color='orange',edgecolor='black')

# Add labels and title
plt.title('Number of Passengers in Each Class')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.grid()
# Show the plot
plt.show()

# %% [markdown]
# ### 3. plot a  histogram of  'age' column to visualize the distrubution of ages

# %%
plt.figure(figsize=(16, 9))
plt.hist(df1['Age'].dropna(), bins=20, color='skyblue', edgecolor='black')

# Add title and axis labels
plt.title('Distribution of Passenger Ages')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.grid(color='skyblue')
plt.show()

# %% [markdown]
# ### 4. create a scatter plot comparing 'age' and 'fare'. add label and a title to the plot

# %%
plt.scatter(df1.Age,df1.Fare,marker='o',color='orange');
plt.xlabel('age')
plt.ylabel('fare')
plt.title('age and fare distribution')
plt.grid()

# %% [markdown]
# ## 5. Create a pie chart showing the percentage of survivors vs non-survivors.

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Count survivors (1) vs non-survivors (0)
survival_counts = df1['Survived'].value_counts()

# Plot pie chart
plt.figure(figsize=(6, 6))
plt.pie(survival_counts, labels=['Did Not Survive', 'Survived'], autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'])
plt.title('Survivors vs Non-Survivors')
plt.show()

# %% [markdown]
# ## 7. Create two subplots side-by-side: - Left: Bar chart of survival count by gender - Right: Pie chart of 'Embarked' values

# %%
gender_counts = df1['Sex'].value_counts()

# Plot bar chart
gender_counts.plot(kind='bar')

# Labels and title
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.title('Passenger Count by Gender')
plt.show()

# %%
# Count how many passengers embarked at each port
embarked_counts = df1['Embarked'].value_counts()

# Plot pie chart
plt.pie(embarked_counts, labels=embarked_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Passenger Distribution by Embarkation Port')
plt.axis('equal')  # Equal aspect ratio ensures pie is circular
plt.show()

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1,2,1)
gender_counts = df1['Sex'].value_counts()

# Plot bar chart
gender_counts.plot(kind='bar')

# Labels and title
plt.xlabel('Gender')
plt.ylabel('Number of Passengers')
plt.title('Passenger Count by Gender')

plt.subplot(1,2,2)
embarked_counts = df1['Embarked'].value_counts()

# Plot pie chart
plt.pie(embarked_counts, labels=embarked_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Passenger Distribution by Embarkation Port')
plt.axis('equal')  # Equal aspect ratio ensures pie is circular
plt.show()

# %% [markdown]
# ## 11. Create a stacked bar plot showing the number of survivors and non-survivors in each passenger class.

# %%
import pandas as pd
import matplotlib.pyplot as plt

survival_counts = df1.groupby(['Pclass', 'Survived']).size().unstack()

# Rename columns for clarity (0 = Did not survive, 1 = Survived)
survival_counts.columns = ['Did Not Survive', 'Survived']

# Plot stacked bar chart
survival_counts.plot(kind='bar', stacked=True, color=['tomato', 'mediumseagreen'])

# Add labels and title
plt.title('Survivors and Non-Survivors by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Number of Passengers')
plt.legend(title='Survival Status')
plt.xticks(rotation=0)

# Show plot
plt.tight_layout()
plt.show()
